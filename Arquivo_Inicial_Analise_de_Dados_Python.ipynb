# %% [markdown]
# <a href="https://colab.research.google.com/github/Victoreli71/-teste-/blob/main/Arquivo_Inicial_Analise_de_Dados_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Desafio:
#
# Você trabalha em uma grande empresa de Cartão de Crédito e o diretor da empresa percebeu que o número de clientes que cancelam seus cartões tem aumentado significativamente, causando prejuízos enormes para a empresa
#
# O que fazer para evitar isso? Como saber as pessoas que têm maior tendência a cancelar o cartão?
#
# # O que temos:
#
# Temos 1 base de dados com informações dos clientes, tanto clientes atuais quanto clientes que cancelaram o cartão
#
# Download da Base de Dados: Botão na página
#
# Referência: https://www.kaggle.com/sakshigoyal7/credit-card-customers

# %% [markdown]
# # Nova seção

# %%
#import pandas as pd
import pandas as pd

# %%
#dataframe = pd.dataframe()
vendas = {'data':['15/02/2005', '16/05/295'],
          'valor':[500,300],
          'produto':['feiao','arroz'],
          'qtde' : ['50', '70'],

          }
vendas_df = pd.DataFrame(vendas)

# %%
display(vendas_df)
# Out:
#          data  valor produto qtde
# 0  15/02/2005    500   feiao   50
# 1   16/05/295    300   arroz   70

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # etapas:
#
# 1- importar a base de dados
#
# 2- vizualizar e tratar a base
#
# 3- analisar a base de dados, verificar, dar uma olhada nos dados
#
# 4- construir a analise para identificar o motivo do cancelamento
#
# - identificar o motivo ou os principais motivos de clientes cancelarem os cartoes de credito

# %%
import pandas as pd


tabela = pd.read_csv("/content/drive/MyDrive/analise de dados-phyton-seg/ClientesBanco.csv", encoding="latin1")

tabela = tabela.drop("CLIENTNUM", axis=1)

display(tabela )
# Out:
#        Categoria  Idade Sexo  Dependentes           Educação   Estado Civil  \
# 0        Cliente     45    M            3       Ensino Médio         Casado
# 1        Cliente     49    F            5    Ensino Superior       Solteiro
# 2        Cliente     51    M            3    Ensino Superior         Casado
# 3        Cliente     40    F            4       Ensino Médio  Não informado
# 4        Cliente     40    M            3  Sem ensino formal         Casado
# ...          ...    ...  ...          ...                ...            ...
# 10122    Cliente     50    M            2    Ensino Superior       Solteiro
# 10123  Cancelado     41    M            2      Não informado     Divorciado
# 10124  Cancelado     44    F            1       Ensino Médio         Casado
# 10125  Cancelado     30    M            2    Ensino Superior  Não informado
# 10126  Cancelado     43    F            2    Ensino Superior         Casado
#
# ...

# %%
tabela = tabela.dropna()
display(tabela.info())

display(tabela.describe(). round(1))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10126 entries, 0 to 10126
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Categoria                      10126 non-null  object
#  1   Idade                          10126 non-null  int64
#  2   Sexo                           10126 non-null  object
#  3   Dependentes                    10126 non-null  int64
#  4   Educação                       10126 non-null  object
#  5   Estado Civil                   10126 non-null  object
#  6   Faixa Salarial Anual           10126 non-null  object
#  7   Categoria Cartão               10126 non-null  object
#  8   Meses como Cliente             10126 non-null  int64
#  9   Produtos Contratados           10126 non-null  int64
#  10  Inatividade 12m                10126 non-null  int64
#  11  Contatos 12m                   10126 non-null  int64
# ...

# %%
qtd_categoria = tabela["Categoria"].value_counts()

qtd_categoria_perc = tabela["Categoria"].value_counts(normalize=True)

display(qtd_categoria)

display(qtd_categoria_perc)
# Out:
# Categoria
# Cliente      8499
# Cancelado    1627
# Name: count, dtype: int64
# Categoria
# Cliente      0.839325
# Cancelado    0.160675
# Name: proportion, dtype: float64

# %%
import plotly.express as px

for coluna in tabela:

 grafico = px.histogram(tabela, x=coluna, color="Categoria")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

for coluna in tabela:
  df = pd.DataFrame(tabela[coluna])
  fig = px.box(df, y=coluna)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
